# %% [markdown]
# # 0. Planeación y Definición del Problema de Investigación
#
# **Proyecto:** Análisis de Nacimientos en Guatemala
# **Período:** 2009-2022
# **Fuente:** Instituto Nacional de Estadística (INE) de Guatemala
# **Total de Registros:** 5,195,195 nacimientos
#
# ---

# %% [markdown]
# ## 0.1 Contexto del Estudio
#
# Los datos de nacimientos provienen de los registros oficiales del INE de Guatemala, cubriendo un período de 14 años (2009-2022). Cada registro representa un nacimiento individual con información demográfica, geográfica y de salud materno-infantil.
#
# Este análisis busca responder preguntas específicas sobre factores de riesgo perinatal, utilizando técnicas de minería de datos para extraer patrones y relaciones que puedan informar políticas públicas de salud.

# %% [markdown]
# ---
# ## 0.2 SITUACIÓN PROBLEMÁTICA
#
# Guatemala enfrenta desafíos significativos en salud materno-infantil que se reflejan en los datos de nacimientos:
#
# ### Problema 1: Alto Índice de Bajo Peso al Nacer
# - El bajo peso al nacer (<2,500 gramos) es un indicador crítico de mortalidad y morbilidad infantil
# - Los datos preliminares muestran prevalencias superiores al 10%, lo cual la OMS considera problemático
# - El bajo peso está asociado con:
#   - Mayor riesgo de mortalidad neonatal e infantil
#   - Problemas de desarrollo cognitivo y físico a largo plazo
#   - Mayor carga económica en el sistema de salud
#
# ### Problema 2: Embarazo Adolescente
# - Guatemala presenta altas tasas de embarazo en menores de 20 años
# - Las madres adolescentes enfrentan:
#   - Mayor riesgo biológico por inmadurez reproductiva
#   - Barreras socioeconómicas (deserción escolar, pobreza)
#   - Menor acceso a servicios de salud prenatal
#
# ### Problema 3: Desigualdad Geográfica
# - Existe heterogeneidad marcada entre departamentos en:
#   - Acceso a servicios de salud
#   - Indicadores de salud materno-infantil
#   - Recursos hospitalarios y personal calificado
# - Esta desigualdad no ha sido cuantificada sistemáticamente en el período 2009-2022
#
# ### Problema 4: Falta de Evidencia Cuantitativa Local
# - Aunque existe literatura internacional, la evidencia específica para Guatemala es limitada
# - No se ha realizado un análisis exhaustivo de los 5.2 millones de nacimientos en este período
# - Los patrones temporales de evolución (2009-2022) no están documentados

# %% [markdown]
# ---
# ## 0.3 PROBLEMA CIENTÍFICO
#
# ### Pregunta Principal de Investigación:
#
# **¿Cuáles son los factores demográficos (edad materna) y geográficos (departamento de residencia) que mejor predicen el riesgo de bajo peso al nacer en Guatemala durante el período 2009-2022, y cómo han evolucionado temporalmente estos patrones?**
#
# ### Subpreguntas Específicas:
#
# 1. **Demográfica:** ¿Cuál es la relación entre la edad de la madre y el peso al nacer?
# 2. **Geográfica:** ¿Qué departamentos presentan mayor prevalencia de bajo peso al nacer?
# 3. **Temporal:** ¿Cómo ha evolucionado la tasa de embarazo adolescente entre 2009 y 2022?
# 4. **Bivariada:** ¿Existe interacción entre edad materna y ubicación geográfica en el riesgo de bajo peso?
# 5. **Multivariada:** ¿Se pueden identificar perfiles de riesgo distintos mediante técnicas de clustering?
#
# ### Justificación:
#
# Este problema es relevante porque:
# - **Salud pública:** El bajo peso al nacer es prevenible con intervenciones adecuadas
# - **Equidad:** Identificar desigualdades geográficas permite focalizar recursos
# - **Evidencia:** Cuantificar riesgos con 5.2 millones de registros proporciona solidez estadística
# - **Política:** Los hallazgos pueden informar programas de salud materno-infantil

# %% [markdown]
# ---
# ## 0.4 OBJETIVOS DE LA INVESTIGACIÓN
#
# ### Objetivo General:
#
# **Identificar y cuantificar los patrones demográficos, geográficos y temporales asociados al bajo peso al nacer en Guatemala durante el período 2009-2022, mediante técnicas de minería de datos y análisis exploratorio.**
#
# ### Objetivos Específicos:
#
# 1. **Caracterizar el dataset:**
#    - Describir las dimensiones del dataset (n, variables, tipos)
#    - Documentar la distribución de variables clave (edad materna, peso al nacer, ubicación)
#    - Evaluar la calidad de los datos y tratamiento de valores faltantes
#
# 2. **Cuantificar la relación edad-peso:**
#    - Comparar el peso promedio al nacer según grupos de edad materna
#    - Calcular el riesgo relativo de bajo peso en adolescentes vs. adultas
#    - Evaluar si existe un patrón "en U" (mayor riesgo en extremos de edad)
#
# 3. **Identificar desigualdades geográficas:**
#    - Determinar qué departamentos tienen mayor prevalencia de bajo peso
#    - Comparar indicadores de embarazo adolescente por departamento
#    - Evaluar diferencias en acceso a servicios de salud según ubicación
#
# 4. **Analizar evolución temporal:**
#    - Comparar tasas de embarazo adolescente entre 2009 y 2022
#    - Evaluar tendencias en peso promedio al nacer a lo largo del período
#    - Identificar cambios en la distribución geográfica de los nacimientos
#
# 5. **Identificar perfiles de riesgo:**
#    - Aplicar técnicas de clustering (K-means) para identificar grupos homogéneos
#    - Caracterizar cada cluster según variables demográficas y de salud
#    - Proponer perfiles de riesgo para priorización de intervenciones
#
# 6. **Generar recomendaciones:**
#    - Sintetizar hallazgos clave del análisis exploratorio
#    - Identificar poblaciones prioritarias para intervención
#    - Sugerir indicadores de monitoreo para políticas públicas

# %% [markdown]
# ---
# ## 0.5 HIPÓTESIS DE INVESTIGACIÓN
#
# Las siguientes hipótesis se plantean basándose en evidencia internacional y exploración preliminar de los datos. Serán validadas o refutadas mediante el análisis exploratorio.
#
# ### H1: Edad Materna y Bajo Peso (Patrón en "U")
#
# **Hipótesis:** *Las madres adolescentes (<20 años) y las madres de edad avanzada (≥35 años) presentan mayor frecuencia de bajo peso al nacer comparadas con madres adultas jóvenes (20-34 años).*
#
# - **Justificación biológica:**
#   - Adolescentes: inmadurez reproductiva, competencia nutricional madre-feto
#   - Edad avanzada: mayor riesgo de hipertensión gestacional, diabetes, complicaciones placentarias
# - **Validación:** Análisis bivariado (edad × peso) y comparación de proporciones
# - **Métrica:** Riesgo relativo de bajo peso por grupo de edad
#
# ### H2: Desigualdad Geográfica en Bajo Peso
#
# **Hipótesis:** *Existe variación geográfica significativa en la prevalencia de bajo peso al nacer entre departamentos, con mayor prevalencia en departamentos rurales y del occidente del país.*
#
# - **Justificación:** Desigualdad en acceso a servicios de salud, nutrición materna y desarrollo socioeconómico
# - **Validación:** Análisis bivariado (departamento × peso) y comparación de promedios
# - **Métrica:** % de bajo peso por departamento, ranking de prevalencia
#
# ### H3: Reducción Temporal del Embarazo Adolescente
#
# **Hipótesis:** *La tasa de embarazo adolescente ha disminuido entre 2009 y 2022, reflejando mejoras en acceso a educación sexual y anticonceptivos.*
#
# - **Justificación:** Tendencia internacional hacia reducción de embarazo adolescente
# - **Validación:** Análisis temporal (% adolescentes por año)
# - **Métrica:** Cambio porcentual entre 2009 y 2022
#
# ### H4: Interacción Edad-Geografía
#
# **Hipótesis:** *El efecto de la edad materna sobre el peso al nacer varía según el departamento de residencia, siendo más pronunciado en departamentos con menor acceso a servicios de salud.*
#
# - **Justificación:** La atención prenatal puede mitigar riesgos biológicos
# - **Validación:** Análisis estratificado (edad × peso por departamento)
# - **Métrica:** Diferencia en riesgo relativo entre departamentos
#
# ### H5: Existencia de Perfiles de Riesgo Distintos
#
# **Hipótesis:** *Se identifican al menos 2 perfiles claramente diferenciados de riesgo perinatal mediante clustering multivariado: un grupo de alto riesgo (madres jóvenes, bajo peso, menor acceso) y un grupo de bajo riesgo.*
#
# - **Justificación:** Estratificación natural de la población según acceso a servicios
# - **Validación:** K-means clustering con variables demográficas y de salud
# - **Métrica:** Silhouette score, caracterización de clusters

# %% [markdown]
# ---
# ## 0.6 DICCIONARIO DE VARIABLES
#
# El dataset integrado contiene **36 variables** clasificadas en grupos temáticos.

# %% [markdown]
# ### 📅 VARIABLES TEMPORALES (6 variables)
#
# Fechas de ocurrencia y registro del nacimiento.
#
# | Variable | Tipo | Descripción | Valores | Uso |
# |----------|------|-------------|---------|-----|
# | **Añoocu** | Numérica | Año de ocurrencia del nacimiento | 2009-2022 | Análisis temporal, filtro principal |
# | **Mesocu** | Numérica | Mes de ocurrencia del nacimiento | 1-12 | Análisis estacional |
# | **Diaocu** | Numérica | Día de ocurrencia del nacimiento | 1-31 | Construcción de fecha completa |
# | **Añoreg** | Numérica | Año de registro del nacimiento | 2009-2022+ | Control de calidad, retrasos |
# | **Mesreg** | Numérica | Mes de registro del nacimiento | 1-12 | Control de calidad |
# | **Diareg** | Numérica | Día de registro del nacimiento | 1-31 | Control de calidad |

# %% [markdown]
# ### 👥 VARIABLES DEMOGRÁFICAS DE LA MADRE (4 variables)
#
# Características personales de la madre.
#
# | Variable | Tipo | Descripción | Valores | Uso |
# |----------|------|-------------|---------|-----|
# | **Edadm** | Numérica | Edad de la madre en años | 10-55 años (validado) | Variable clave del análisis |
# | **Escivm** | Categórica | Estado civil de la madre | 1=Unida, 2=Casada, 3=Soltera, 4=Divorciada, 5=Viuda, 6=Separada, 9=Ignorado | Indicador socioeconómico |
# | **Depnam** | Numérica | Departamento de nacimiento de madre | 1-22 (códigos INE) | Migración interna |
# | **Edadp** | Numérica | Edad del padre en años | 10-99 años (con errores) | Uso limitado (79% faltante) |

# %% [markdown]
# ### 👶 VARIABLES DEL RECIÉN NACIDO (5 variables)
#
# Características del bebé al nacer.
#
# | Variable | Tipo | Descripción | Valores | Uso |
# |----------|------|-------------|---------|-----|
# | **Sexo** | Categórica | Sexo del recién nacido | 1=Masculino, 2=Femenino | Análisis diferencial por sexo |
# | **Libras** | Numérica | Peso al nacer en libras | 0-15 libras | Conversión a gramos |
# | **Onzas** | Numérica | Peso al nacer en onzas | 0-15 onzas | Conversión a gramos |
# | **Peso_gramos** | Numérica | Peso al nacer en gramos (calculado) | 500-6,000 g (validado) | **Variable dependiente principal** |
# | **Tipar** | Categórica | Tipo de parto | 1=Simple, 2=Doble/Gemelar, 3=Triple+ | Control de gestación múltiple |

# %% [markdown]
# ### 🏥 VARIABLES DE ATENCIÓN DEL PARTO (2 variables)
#
# Lugar y asistencia recibida durante el nacimiento.
#
# | Variable | Tipo | Descripción | Valores | Uso |
# |----------|------|-------------|---------|-----|
# | **Sitioocu** | Categórica | Sitio donde ocurrió el nacimiento | 1=Hospital, 2=Centro salud, 3=Casa, etc. | Acceso a servicios |
# | **Asisrec** | Categórica | Tipo de asistencia recibida | 1=Médico, 2=Comadrona, 3=Enfermera, etc. | Calidad de atención |

# %% [markdown]
# ### 🗺️ VARIABLES GEOGRÁFICAS (7 variables)
#
# Ubicación del nacimiento y residencia de los padres.
#
# | Variable | Tipo | Descripción | Valores | Uso |
# |----------|------|-------------|---------|-----|
# | **Depocu** | Numérica | Departamento donde ocurrió el nacimiento | 1-22 (códigos INE) | Análisis espacial de servicios |
# | **Mupocu** | Numérica | Municipio donde ocurrió el nacimiento | Códigos INE | Análisis granular (opcional) |
# | **Deprem** | Numérica | Departamento de residencia de la madre | 1-22 (códigos INE) | **Variable geográfica principal** |
# | **Deprep** | Numérica | Departamento de residencia del padre | 1-22 (códigos INE) | Análisis de migración |
# | **Depreg** | Numérica | Departamento de registro | 1-22 (códigos INE) | Control administrativo |
# | **Depnap** | Numérica | Departamento de nacimiento del padre | 1-22 (códigos INE) | Análisis de migración |
# | **Areag** | Categórica | Área geográfica | 1=Urbana, 2=Rural | Análisis urbano-rural (no en todos los años) |

# %% [markdown]
# ### 👨‍👩‍👧‍👦 VARIABLES DE FECUNDIDAD (3 variables)
#
# Historia reproductiva de la madre.
#
# | Variable | Tipo | Descripción | Valores | Uso |
# |----------|------|-------------|---------|-----|
# | **Tohite** | Numérica | Total de hijos tenidos (incluyendo actual) | 1-20 (validado) | Paridad, experiencia reproductiva |
# | **Tohivi** | Numérica | Total de hijos vivos | 0-20 | Mortalidad infantil previa |
# | **Tohinm** | Numérica | Total de hijos nacidos muertos | 0-10 | Riesgo reproductivo |

# %% [markdown]
# ### 🏷️ VARIABLES DERIVADAS - CATEGÓRICAS (5 variables)
#
# Creadas durante la limpieza para facilitar análisis.
#
# | Variable | Tipo | Descripción | Categorías | Uso |
# |----------|------|-------------|------------|-----|
# | **Grupo_edad_madre** | Categórica | Grupo de edad materna (3 categorías) | Adolescente (10-19), Adulta joven (20-34), Adulta (35-55) | Análisis comparativo de grupos |
# | **Grupo_edad_detallado** | Categórica | Grupo de edad materna (8 categorías) | 10-14, 15-19, 20-24, 25-29, 30-34, 35-39, 40-44, 45-55 | Análisis granular |
# | **Categoria_peso** | Categórica | Clasificación OMS del peso | Muy bajo (<1500g), Bajo (1500-2499g), Normal (2500-3999g), Macrosomía (≥4000g) | Clasificación clínica |
# | **Sexo_nombre** | Categórica | Sexo en texto | Masculino, Femenino | Presentación de resultados |
# | **Tipo_parto** | Categórica | Tipo de parto en texto | Simple, Doble, Triple o más | Presentación de resultados |

# %% [markdown]
# ### 🎯 VARIABLES DERIVADAS - INDICADORES BINARIOS (5 variables)
#
# Indicadores de riesgo o características específicas.
#
# | Variable | Tipo | Descripción | Valores | Uso |
# |----------|------|-------------|---------|-----|
# | **Bajo_peso** | Binaria | Indicador de bajo peso al nacer | 1=Sí (<2500g), 0=No (≥2500g) | **Variable dependiente binaria** |
# | **Madre_adolescente** | Binaria | Indicador de madre adolescente | 1=Sí (<20 años), 0=No | Población de riesgo |
# | **Madre_35_mas** | Binaria | Indicador de madre de edad avanzada | 1=Sí (≥35 años), 0=No | Población de riesgo |
# | **Primer_hijo** | Binaria | Indicador de primer hijo | 1=Sí (Tohite=1), 0=No | Primiparidad vs multiparidad |
# | **registro_completo** | Binaria | Indicador de registro con variables clave completas | 1=Completo, 0=Incompleto | Control de calidad |

# %% [markdown]
# ### 📊 RESUMEN DEL DICCIONARIO
#
# | Grupo de Variables | Cantidad | Variables Clave |
# |-------------------|----------|----------------|
# | **Temporales** | 6 | Añoocu |
# | **Demográficas (madre)** | 4 | Edadm, Escivm |
# | **Recién nacido** | 5 | Peso_gramos, Sexo |
# | **Atención parto** | 2 | Sitioocu, Asisrec |
# | **Geográficas** | 7 | Deprem, Depocu |
# | **Fecundidad** | 3 | Tohite |
# | **Derivadas categóricas** | 5 | Grupo_edad_madre, Categoria_peso |
# | **Derivadas binarias** | 5 | Bajo_peso, Madre_adolescente |
# | **TOTAL** | **36** | |
#
# ### Variables Principales para el Análisis:
#
# - **Variable dependiente:** `Peso_gramos` (continua), `Bajo_peso` (binaria)
# - **Variables independientes principales:** `Edadm`, `Grupo_edad_madre`, `Deprem`
# - **Variables de control:** `Sexo`, `Tipar`, `Tohite`, `Añoocu`
# - **Variables de contexto:** `Sitioocu`, `Asisrec`, `Escivm`

# %% [markdown]
# ---
# ## 0.7 METODOLOGÍA GENERAL
#
# El análisis se estructura en 6 etapas secuenciales, cada una documentada en un notebook específico:

# %% [markdown]
# ### Etapa 1: Carga y Unión de Datos (Notebook 01)
#
# **Objetivo:** Construir un dataset único y coherente a partir de 14 archivos SPSS.
#
# **Actividades:**
# - Carga individual de archivos .sav (2009-2022)
# - Verificación de estructura y consistencia de variables
# - Identificación de variables comunes a todos los años
# - Unión vertical (concatenación) de todos los años
# - Validación de integridad (totales coincidentes)
# - Guardado del dataset unificado
#
# **Herramientas:** Python, pandas, pyreadstat

# %% [markdown]
# ### Etapa 2: Limpieza y Preparación (Notebook 02)
#
# **Objetivo:** Validar, limpiar y preparar los datos para análisis.
#
# **Actividades:**
# - Validación de rangos:
#   - Edad madre: 10-55 años
#   - Peso: 500-6,000 gramos (tras conversión Libras+Onzas → gramos)
#   - Total hijos: 1-20 hijos
# - Tratamiento de valores faltantes (documentado, no eliminación)
# - Creación de variables derivadas:
#   - Grupos de edad materna
#   - Categorías de peso según OMS
#   - Indicadores binarios de riesgo
# - Análisis de completitud de datos
# - Guardado del dataset limpio
#
# **Herramientas:** Python, pandas, numpy, matplotlib

# %% [markdown]
# ### Etapa 3: Descripción del Dataset (Notebook 03)
#
# **Objetivo:** Responder "¿Qué datos tengo?"
#
# **Actividades:**
# - Reporte de dimensiones (n observaciones, n variables)
# - Clasificación de variables (numéricas vs categóricas)
# - Agrupación temática de variables
# - Estadísticas descriptivas básicas
# - Documentación de tipos de datos
#
# **Salida:** Caracterización completa del dataset

# %% [markdown]
# ### Etapa 4: Análisis Univariado (Notebook 04)
#
# **Objetivo:** Estudiar cada variable por separado.
#
# **Actividades:**
# - **Variables numéricas:**
#   - Estadísticas descriptivas (media, mediana, desv.std, cuartiles)
#   - Histogramas y boxplots
#   - Tests de normalidad (Q-Q plots, Shapiro-Wilk)
#   - Identificación de outliers
# - **Variables categóricas:**
#   - Tablas de frecuencia
#   - Gráficos de barras y proporciones
#   - Identificación de categorías dominantes
#
# **Variables Analizadas:**
# - Edad materna
# - Peso al nacer
# - Total de hijos
# - Sexo, estado civil, departamento, sitio del parto
#
# **Herramientas:** scipy.stats, seaborn, matplotlib

# %% [markdown]
# ### Etapa 5: Análisis Bivariado (Notebook 05)
#
# **Objetivo:** Encontrar relaciones entre pares de variables.
#
# **Actividades:**
# - **Cruces principales:**
#   1. Edad materna × Peso al nacer
#   2. Edad materna × Estado civil
#   3. Peso al nacer × Departamento
#   4. Edad materna × Departamento
#   5. Peso al nacer × Año (evolución temporal)
# - **Técnicas:**
#   - Correlaciones (Pearson)
#   - Tablas cruzadas (crosstabs)
#   - Comparación de promedios por grupo
#   - Cálculo de riesgo relativo
#   - Gráficos de dispersión, boxplots por grupo, barras apiladas
#
# **Validación de Hipótesis:** H1, H2, H3, H4

# %% [markdown]
# ### Etapa 6: Análisis Multivariado (Notebook 06)
#
# **Objetivo:** Explorar estructuras complejas y patrones ocultos.
#
# **Actividades:**
# - **Matriz de correlaciones:** Identificar colinealidad
# - **PCA (Análisis de Componentes Principales):**
#   - Reducción de dimensionalidad
#   - Varianza explicada por componentes
#   - Biplot de variables
# - **Clustering K-means:**
#   - Determinación del número óptimo de clusters (método del codo, Silhouette)
#   - Caracterización de clusters identificados
#   - Perfiles de riesgo
# - **Clustering jerárquico:**
#   - Dendrograma
#   - Validación de estructura de grupos
#
# **Validación de Hipótesis:** H5
#
# **Herramientas:** scikit-learn, scipy.cluster

# %% [markdown]
# ### Consideraciones Metodológicas:
#
# 1. **Tamaño muestral:** 5.2 millones de registros proporcionan poder estadístico excepcional
# 2. **Valores faltantes:** Se documenta pero no se imputa (análisis con datos disponibles)
# 3. **Outliers:** Se validan biológicamente, no se eliminan automáticamente
# 4. **Normalidad:** Se evalúa pero no se asume (se usan métodos robustos)
# 5. **Causalidad:** Este es un estudio observacional; las asociaciones no implican causalidad
# 6. **Reproducibilidad:** Todo el código está documentado en notebooks ejecutables

# %% [markdown]
# ---
# ## 0.8 PLAN DE ANÁLISIS PARA VALIDAR HIPÓTESIS
#
# | Hipótesis | Notebook | Técnica | Métrica de Validación |
# |-----------|----------|---------|----------------------|
# | **H1: Patrón en "U"** | 05 | Análisis bivariado (edad × peso) | Riesgo relativo de bajo peso por grupo de edad |
# | **H2: Desigualdad geográfica** | 05 | Análisis bivariado (depto × peso) | % bajo peso por departamento, ranking |
# | **H3: Reducción temporal** | 05 | Análisis temporal | % embarazo adolescente 2009 vs 2022 |
# | **H4: Interacción edad-geografía** | 05 | Análisis estratificado | RR de bajo peso (adolescentes) por departamento |
# | **H5: Perfiles de riesgo** | 06 | K-means clustering | Silhouette score, caracterización clusters |

# %% [markdown]
# ---
# ## 0.9 INDICADORES CLAVE A REPORTAR
#
# Al finalizar el análisis, se reportarán los siguientes indicadores:
#
# ### Descriptivos:
# - Peso promedio al nacer (nacional y por grupo)
# - Prevalencia de bajo peso (<2,500g)
# - Prevalencia de embarazo adolescente
# - Edad promedio de la madre
# - Distribución geográfica de nacimientos
#
# ### Comparativos:
# - Riesgo relativo de bajo peso (adolescentes vs adultas)
# - Diferencia de peso promedio entre grupos de edad
# - Ranking de departamentos por prevalencia de bajo peso
# - Cambio temporal 2009-2022 en indicadores clave
#
# ### Multivariados:
# - Número óptimo de clusters identificados
# - Caracterización demográfica de cada cluster
# - % de varianza explicada por componentes principales
# - Correlaciones significativas entre variables

# %% [markdown]
# ---
# ## 0.10 LIMITACIONES DEL ESTUDIO
#
# Es importante reconocer las siguientes limitaciones:
#
# 1. **Datos secundarios:** No se controló el proceso de recolección original
# 2. **Valores faltantes:** Especialmente en edad del padre (79% faltante)
# 3. **Causación:** Estudio observacional; no se pueden establecer relaciones causales
# 4. **Variables no disponibles:**
#    - Control prenatal (número de consultas)
#    - Nutrición materna
#    - Comorbilidades (diabetes, hipertensión)
#    - Nivel socioeconómico directo
# 5. **Heterogeneidad temporal:** Posibles cambios en criterios de registro a lo largo de 14 años
# 6. **Sesgo de registro:** Subregistro potencial en áreas rurales remotas

# %% [markdown]
# ---
# ## 0.11 SIGUIENTES PASOS
#
# Con la planeación establecida, se procede a:
#
# 1. ✅ **Notebook 01:** Carga y unión de datos
# 2. ✅ **Notebook 02:** Limpieza y preparación
# 3. ✅ **Notebook 03:** Descripción del dataset
# 4. ✅ **Notebook 04:** Análisis univariado
# 5. ✅ **Notebook 05:** Análisis bivariado
# 6. ⚠️ **Notebook 06:** Análisis multivariado (pendiente corrección)
# 7. 📝 **Informe final:** Síntesis de hallazgos y recomendaciones
#
# ---
#
# **Nota:** Este notebook de planeación establece el marco conceptual y metodológico. Los notebooks posteriores ejecutan cada etapa del análisis guiándose por los objetivos e hipótesis aquí definidos.
